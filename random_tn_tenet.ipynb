# %%
#Adding the needed depedencies to the notebook
using QuacIO
using Makie
using GLMakie
using Tenet
using EinExprs
Makie.inline!(true)
# Out:
# true

# %%
seed1 = 12345
seed2= 67890


TN = rand(TensorNetwork, 5::Integer, 4::Integer; out = 0, dim = 1:2, seed = seed1, globalind = false)
plot(TN, labels=true)

# %%
path = einexpr(TN, optimizer = Greedy)
print(path)
# Out:
# EinExpr(Symbol[], EinExpr[EinExpr([:F, :J, :G, :C], EinExpr[], Dict(:F => 2, :J => 1, :G => 2, :C => 1)), EinExpr([:F, :C, :G, :J], EinExpr[EinExpr([:F, :C, :A, :H], EinExpr[EinExpr([:I, :F, :C], EinExpr[], Dict(:I => 2, :F => 2, :C => 1)), EinExpr([:A, :H, :I], EinExpr[], Dict(:I => 2, :A => 2, :H => 1))], Dict{Symbol, Int64}()), EinExpr([:A, :G, :H, :J], EinExpr[EinExpr([:D, :A, :B, :G, :E, :H], EinExpr[], Dict(:A => 2, :G => 2, :D => 2, :H => 1, :B => 2, :E => 2)), EinExpr([:B, :E, :J, :D], EinExpr[], Dict(:J => 1, :D => 2, :B => 2, :E => 2))], Dict{Symbol, Int64}())], Dict{Symbol, Int64}())], Dict{Symbol, Int64}())
