#    7
#    8
#    9
#   10
#    ⋮
#   92
#   93
#   94
#   95
#   96
#   97
#   98
#   99
#  100

# %%
p = scatter(numgames, xlabel="Game number", ylabel="Average loop size in path", trained_average_length,  label="Trained average loop size", color =:green)
meanltrain = mean((trained_average_length))
hline!(p, [meanltrain, meanltrain],
         label="Trained mean average loop size",
         linestyle=:dash,
         color=:green) # Change the color to match the trained rewards color

scatter!(numgames,  random_average_length, color =:red, label="Random average loop size")

meanlrandom = mean((random_average_length))
hline!(p, [meanlrandom, meanlrandom],
         label="Random mean average loop size",
         linestyle=:dash,
         color=:red) # Change the color to match the trained rewards color

println(meanltrain)
println(meanlrandom)
# Out:
# 4.91909090909091
# 5.201818181818182

# %%
mean_trained_rewards = mean(abs.(trained_rewards))
mean_random_rewards = mean(abs.(random_rewards))
println("mean trained = ", mean_trained_rewards)
println("mean random = ", mean_random_rewards)

p = scatter(numgames, xlabel="Game number", ylabel="Accumulated computational cost", abs.(trained_rewards), yscale=:log10, label="Trained costs", color =:green)

hline!(p, [mean_trained_rewards, mean_trained_rewards],
         label="Mean trained cost",
         linestyle=:dash,
         color=:green) # Change the color to match the trained rewards color

scatter!(p, numgames, abs.(random_rewards), label="Random costs", color =:red)


hline!(p, [mean_random_rewards, mean_random_rewards],
         label="Mean random cost",
         linestyle=:dash,
         color=:red) # Change the color to match the random rewards color

display(p)

relative_rewards = abs.(trained_rewards) ./ abs.(random_rewards)
mean_relative_rewards = mean(relative_rewards)
formatted_mean = @sprintf("%.6f", mean_relative_rewards)

p = scatter(numgames, relative_rewards, label="Relative costs", ylim = [0,1], color=:orange)
hline!(p, [mean_relative_rewards, mean_relative_rewards],
         label="Mean relative costs = $formatted_mean", xlabel="Game number", ylabel="Relative cost trained/random",
         linestyle=:dash,
         color=:orange)

display(p)
# Out:
# mean trained = 177286.55
# mean random = 3.82971219e6

# %%
using Plots

# extract data from the .jsons and plot with ticks to visualise the specifics
iterations = [0, 1, 2, 3]
num_boards = [0, 7200, 14400, 21600]
num_distinct_boards = [0, 4461, 8447, 12241]

# Create the line plot
p = plot(
    iterations, num_boards, 
    label = "Number of boards",
    xlabel = "Iteration",
    ylabel = "Experience Buffer Size",
    legend = :topleft, color=:blue
)

# Add the second line plot
plot!(p, iterations, num_distinct_boards, label = "Number of distinct boards", color=:orange)

# Add scatter plots
scatter!(p, iterations, num_boards, color=:blue, label="")
scatter!(p, iterations, num_distinct_boards,label="", color=:orange)

# Set the y-axis ticks
yticks_values = union(num_boards, num_distinct_boards)
yticks_labels = string.(yticks_values)  # Convert numbers to strings
yticks!(p, yticks_values, yticks_labels)

# Display the plot
display(p)
